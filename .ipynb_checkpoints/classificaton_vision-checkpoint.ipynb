# %%
import tensorflow as tf
import numpy as np
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import gridplot
output_notebook()
print(tf.__version__)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4456">Loading BokehJS ...</span>
#     </div>
# 2.1.2

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
p = figure(plot_width=300,plot_height=300)
p.image(image=[train_images[0][::-1]],x=0,y=0,dw=10,dh=10, palette='Plasma256', level="image")
show(p)
# Out:
#   <div class="bk-root" id="3e2676ca-1444-433a-9b95-e6c2d5519a92" data-root-id="4721"></div>

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
offset = 10
grid_list = []
for i in range(offset,offset+16):
    p = figure(plot_width=150,plot_height=150,title=class_names[train_labels[i]],title_location='below')
    p.image(image=[train_images[i][::-1]],x=0,y=0,dw=10,dh=10,palette='Greys256',level='image')
    grid_list.append(p)
show(gridplot(grid_list, ncols=4))
# Out:
#   <div class="bk-root" id="5271b7c2-392e-4839-a76e-36130dc68b63" data-root-id="8411"></div>

# %%
layers = [tf.keras.layers.Flatten(input_shape=train_images[0].shape)]
layers.append(tf.keras.layers.Dense(128, activation='relu'))
layers.append(tf.keras.layers.Dense(10))
model = tf.keras.Sequential(layers)

# %%
model.compile(optimizer='adam',
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

# %%
model.fit(train_images,train_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.4913 - accuracy: 0.8265
# Epoch 2/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.3714 - accuracy: 0.8659
# Epoch 3/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.3356 - accuracy: 0.8776
# Epoch 4/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.3097 - accuracy: 0.8866
# Epoch 5/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2940 - accuracy: 0.8911
# Epoch 6/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2804 - accuracy: 0.8962
# Epoch 7/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.2686 - accuracy: 0.8999
# Epoch 8/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2547 - accuracy: 0.9061
# Epoch 9/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2475 - accuracy: 0.9081
# Epoch 10/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2390 - accuracy: 0.9102

# %%
test_loss, test_acc = model.evaluate(test_images,test_labels, verbose=2)
print(test_loss, test_acc)
# Out:
# 10000/10000 - 1s - loss: 0.3293 - accuracy: 0.8862
# 0.32929805057644845 0.8862
